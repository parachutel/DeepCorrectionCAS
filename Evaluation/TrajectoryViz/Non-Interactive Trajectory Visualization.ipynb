# %%
include("trajViz.jl")
# Out:
# interactiveTrajViz

# %%
trajViz(x0=0.0,
        y0=0.0,
        x_dest=2500.0,
        y_dest=-400.0, 
        CASType=:correctedSector,
        policyFile="LOWFI_mid3_maxdist_2km_nmac_150m_Discount_0.95_ActWeight_0.5_IfSample_false_PenAction_3.0_PenConflict_50.0_PenCloseness_500.0_PenNmac_7000.0_Sigma_v_5.0_alert_5.0_theta_3.0_phi_7.0_coc_3.0_2018-11-13T18\:55\:43.491",
        intTrajFile="intTraj.csv",
        figName="")
# Out:
# PGFPlots.GroupPlot(PGFPlots.Axis[PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Linear(Real[0.0 50.0 … 2115.1 2136.5; 300.0 300.0 … -1899.3 -1944.5], "none", nothing, "forget plot, red, very thick", nothing, nothing, nothing), PGFPlots.Plots.Linear(Real[0.0 35.355 … 1934.8 1947.4; -500.0 -535.36 … 364.26 412.64], "none", nothing, "forget plot, magenta, very thick", nothing, nothing, nothing), PGFPlots.Plots.Linear(Real[0.0 50.0 … 1803.7 1820.6; -1200.0 -1200.0 … 1258.5 1305.5], "none", nothing, "forget plot, pink, very thick", nothing, nothing, nothing), PGFPlots.Plots.Linear(Real[49.372 98.7441 … 2130.84 2156.63; -7.89953 -15.7991 … -2132.51 -2175.35], "none", nothing, "forget plot, black, very thick", nothing, nothing, nothing), PGFPlots.Plots.Scatter(Any[49.372 98.7441 … 2130.84 2156.63; -7.89953 -15.7991 … -2132.51 -2175.35; 0.0 0.0 … -10.0 10.0], "*", 1.2, nothing, "Ownship Actions", true, nothing), PGFPlots.Plots.Scatter(Any[0; 0], nothing, 3, "white, mark options={fill=black},mark=square*", "Start", true, nothing), PGFPlots.Plots.Scatter(Any[2500.0; -400.0], nothing, 3, "white, mark options={fill=green},mark=square*", "Destination", true, nothing), PGFPlots.Plots.Scatter(Any[0.0; 300.0], nothing, 3, "forget plot,white, mark options={fill=black},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[2136.5; -1944.5], nothing, 3, "forget plot,white, mark options={fill=green},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[0.0; -500.0], nothing, 3, "forget plot,white, mark options={fill=black},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[1947.4; 412.64], nothing, 3, "forget plot,white, mark options={fill=green},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[0.0; -1200.0], nothing, 3, "forget plot,white, mark options={fill=black},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[1820.6; 1305.5], nothing, 3, "forget plot,white, mark options={fill=green},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[438.46 860.23 … 1770.3 2005.5; 214.56 -50.389 … -1233.4 -1674.6], nothing, 3, "very thick,solid,red,mark=diamond", "Intruder 1", true, nothing), PGFPlots.Plots.Scatter(Any[315.93 701.9 … 1713.0 1868.4; -820.44 -1136.3 … -351.87 123.25], nothing, 3, "very thick,solid,magenta,mark=diamond", "Intruder 2", true, nothing), PGFPlots.Plots.Scatter(Any[425.64 793.99 … 1529.9 1716.7; -1076.2 -741.09 … 560.32 1024.1], nothing, 3, "very thick,solid,pink,mark=diamond", "Intruder 3", true, nothing), PGFPlots.Plots.Scatter(Any[493.72 955.053 … 1806.74 2025.42; -78.9953 -251.3 … -1459.31 -1906.83], nothing, 3, "very thick,solid,black,mark=diamond", "Ownship Trajectory", true, nothing)], "correctedSector", "x (m)", nothing, "y (m)", nothing, nothing, nothing, nothing, nothing, nothing, nothing, true, nothing, nothing, nothing, nothing, "5in", "5in", nothing, nothing, "{at={(0.02,0.02)}, anchor=south west}", nothing, nothing, true, nothing, nothing, "axis"), PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Linear(Real[1.0 2.0 … 65.0 66.0; 311.833 319.539 … 233.74 231.724], "none", nothing, "red, very thick", "Intruder 1", nothing, nothing), PGFPlots.Plots.Linear(Real[1.0 2.0 … 65.0 66.0; 494.571 523.414 … 2504.45 2596.43], "none", nothing, "magenta, very thick", "Intruder 2", nothing, nothing), PGFPlots.Plots.Linear(Real[1.0 2.0 … 65.0 66.0; 1193.12 1185.2 … 3406.75 3497.03], "none", nothing, "pink, very thick", "Intruder 3", nothing, nothing), PGFPlots.Plots.Linear(Real[1.0 2.0 … 65.0 66.0; 150.0 150.0 … 150.0 150.0], "none", nothing, "black, very thick", "NMAC", nothing, nothing)], "Minimum Distance = 45.98056303589702 m", "Time Step (s)", nothing, "Distance (m)", nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, "5in", "2in", nothing, nothing, "{at={(0.05,0.95)}, anchor=north west}", nothing, nothing, nothing, nothing, nothing, "axis")], (1, 2), nothing, "vertical sep = 2cm")

# %%
trajViz(x0=0.0,
        y0=0.0,
        x_dest=2500.0,
        y_dest=-400.0, 
        CASType=:correctedClosest,
        policyFile="LOWFI_mid3_maxdist_2km_nmac_150m_Discount_0.95_ActWeight_0.5_IfSample_false_PenAction_3.0_PenConflict_50.0_PenCloseness_500.0_PenNmac_7000.0_Sigma_v_5.0_alert_5.0_theta_3.0_phi_7.0_coc_3.0_2018-11-13T18\:55\:43.491",
        intTrajFile="intTraj.csv",
        figName="")
# Out:
# PGFPlots.GroupPlot(PGFPlots.Axis[PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Linear(Real[0.0 50.0 … 2115.1 2136.5; 300.0 300.0 … -1899.3 -1944.5], "none", nothing, "forget plot, red, very thick", nothing, nothing, nothing), PGFPlots.Plots.Linear(Real[0.0 35.355 … 1934.8 1947.4; -500.0 -535.36 … 364.26 412.64], "none", nothing, "forget plot, magenta, very thick", nothing, nothing, nothing), PGFPlots.Plots.Linear(Real[0.0 50.0 … 1803.7 1820.6; -1200.0 -1200.0 … 1258.5 1305.5], "none", nothing, "forget plot, pink, very thick", nothing, nothing, nothing), PGFPlots.Plots.Linear(Real[49.372 98.7441 … 2028.39 2046.24; -7.89953 -15.7991 … -2107.5 -2154.21], "none", nothing, "forget plot, black, very thick", nothing, nothing, nothing), PGFPlots.Plots.Scatter(Any[49.372 98.7441 … 2028.39 2046.24; -7.89953 -15.7991 … -2107.5 -2154.21; 0.0 0.0 … 10.0 -10.0], "*", 1.2, nothing, "Ownship Actions", true, nothing), PGFPlots.Plots.Scatter(Any[0; 0], nothing, 3, "white, mark options={fill=black},mark=square*", "Start", true, nothing), PGFPlots.Plots.Scatter(Any[2500.0; -400.0], nothing, 3, "white, mark options={fill=green},mark=square*", "Destination", true, nothing), PGFPlots.Plots.Scatter(Any[0.0; 300.0], nothing, 3, "forget plot,white, mark options={fill=black},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[2136.5; -1944.5], nothing, 3, "forget plot,white, mark options={fill=green},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[0.0; -500.0], nothing, 3, "forget plot,white, mark options={fill=black},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[1947.4; 412.64], nothing, 3, "forget plot,white, mark options={fill=green},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[0.0; -1200.0], nothing, 3, "forget plot,white, mark options={fill=black},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[1820.6; 1305.5], nothing, 3, "forget plot,white, mark options={fill=green},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[438.46 860.23 … 1770.3 2005.5; 214.56 -50.389 … -1233.4 -1674.6], nothing, 3, "very thick,solid,red,mark=diamond", "Intruder 1", true, nothing), PGFPlots.Plots.Scatter(Any[315.93 701.9 … 1713.0 1868.4; -820.44 -1136.3 … -351.87 123.25], nothing, 3, "very thick,solid,magenta,mark=diamond", "Intruder 2", true, nothing), PGFPlots.Plots.Scatter(Any[425.64 793.99 … 1529.9 1716.7; -1076.2 -741.09 … 560.32 1024.1], nothing, 3, "very thick,solid,pink,mark=diamond", "Intruder 3", true, nothing), PGFPlots.Plots.Scatter(Any[493.72 944.403 … 1698.0 1915.65; -78.9953 -270.957 … -1437.36 -1885.39], nothing, 3, "very thick,solid,black,mark=diamond", "Ownship Trajectory", true, nothing)], "correctedClosest", "x (m)", nothing, "y (m)", nothing, nothing, nothing, nothing, nothing, nothing, nothing, true, nothing, nothing, nothing, nothing, "5in", "5in", nothing, nothing, "{at={(0.02,0.02)}, anchor=south west}", nothing, nothing, true, nothing, nothing, "axis"), PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Linear(Real[1.0 2.0 … 65.0 66.0; 311.833 319.539 … 225.534 228.308], "none", nothing, "red, very thick", "Intruder 1", nothing, nothing), PGFPlots.Plots.Linear(Real[1.0 2.0 … 65.0 66.0; 494.571 523.414 … 2473.53 2568.75], "none", nothing, "magenta, very thick", "Intruder 2", nothing, nothing), PGFPlots.Plots.Linear(Real[1.0 2.0 … 65.0 66.0; 1193.12 1185.2 … 3373.49 3467.06], "none", nothing, "pink, very thick", "Intruder 3", nothing, nothing), PGFPlots.Plots.Linear(Real[1.0 2.0 … 65.0 66.0; 150.0 150.0 … 150.0 150.0], "none", nothing, "black, very thick", "NMAC", nothing, nothing)], "Minimum Distance = 162.29 m", "Time Step (s)", nothing, "Distance (m)", nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, "5in", "2in", nothing, nothing, "{at={(0.05,0.95)}, anchor=north west}", nothing, nothing, nothing, nothing, nothing, "axis")], (1, 2), nothing, "vertical sep = 2cm")

# %%
trajViz(x0=0.0,
        y0=0.0,
        x_dest=2500.0,
        y_dest=-400.0, 
        CASType=:VICASMulti,
        policyFile="LOWFI_mid3_maxdist_2km_nmac_150m_Discount_0.95_ActWeight_0.5_IfSample_false_PenAction_3.0_PenConflict_50.0_PenCloseness_500.0_PenNmac_7000.0_Sigma_v_5.0_alert_5.0_theta_3.0_phi_7.0_coc_3.0_2018-11-13T18\:55\:43.491",
        intTrajFile="intTraj.csv",
        figName="")
# Out:
# PGFPlots.GroupPlot(PGFPlots.Axis[PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Linear(Real[0.0 50.0 … 2115.1 2136.5; 300.0 300.0 … -1899.3 -1944.5], "none", nothing, "forget plot, red, very thick", nothing, nothing, nothing), PGFPlots.Plots.Linear(Real[0.0 35.355 … 1934.8 1947.4; -500.0 -535.36 … 364.26 412.64], "none", nothing, "forget plot, magenta, very thick", nothing, nothing, nothing), PGFPlots.Plots.Linear(Real[0.0 50.0 … 1803.7 1820.6; -1200.0 -1200.0 … 1258.5 1305.5], "none", nothing, "forget plot, pink, very thick", nothing, nothing, nothing), PGFPlots.Plots.Linear(Real[48.4957 95.7459 … 1842.02 1863.86; -12.1725 -28.5254 … -2277.95 -2322.92], "none", nothing, "forget plot, black, very thick", nothing, nothing, nothing), PGFPlots.Plots.Scatter(Any[48.4957 95.7459 … 1842.02 1863.86; -12.1725 -28.5254 … -2277.95 -2322.92; -5.0 -5.0 … 10.0 -5.0], "*", 1.2, nothing, "Ownship Actions", true, nothing), PGFPlots.Plots.Scatter(Any[0; 0], nothing, 3, "white, mark options={fill=black},mark=square*", "Start", true, nothing), PGFPlots.Plots.Scatter(Any[2500.0; -400.0], nothing, 3, "white, mark options={fill=green},mark=square*", "Destination", true, nothing), PGFPlots.Plots.Scatter(Any[0.0; 300.0], nothing, 3, "forget plot,white, mark options={fill=black},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[2136.5; -1944.5], nothing, 3, "forget plot,white, mark options={fill=green},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[0.0; -500.0], nothing, 3, "forget plot,white, mark options={fill=black},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[1947.4; 412.64], nothing, 3, "forget plot,white, mark options={fill=green},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[0.0; -1200.0], nothing, 3, "forget plot,white, mark options={fill=black},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[1820.6; 1305.5], nothing, 3, "forget plot,white, mark options={fill=green},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[438.46 860.23 … 1770.3 2005.5; 214.56 -50.389 … -1233.4 -1674.6], nothing, 3, "very thick,solid,red,mark=diamond", "Intruder 1", true, nothing), PGFPlots.Plots.Scatter(Any[315.93 701.9 … 1713.0 1868.4; -820.44 -1136.3 … -351.87 123.25], nothing, 3, "very thick,solid,magenta,mark=diamond", "Intruder 2", true, nothing), PGFPlots.Plots.Scatter(Any[425.64 793.99 … 1529.9 1716.7; -1076.2 -741.09 … 560.32 1024.1], nothing, 3, "very thick,solid,pink,mark=diamond", "Intruder 3", true, nothing), PGFPlots.Plots.Scatter(Any[458.826 934.852 … 1515.13 1733.11; -190.865 -337.238 … -1605.05 -2053.76], nothing, 3, "very thick,solid,black,mark=diamond", "Ownship Trajectory", true, nothing)], "VICASMulti", "x (m)", nothing, "y (m)", nothing, nothing, nothing, nothing, nothing, nothing, nothing, true, nothing, nothing, nothing, nothing, "5in", "5in", nothing, nothing, "{at={(0.02,0.02)}, anchor=south west}", nothing, nothing, true, nothing, nothing, "axis"), PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Linear(Real[1.0 2.0 … 65.0 66.0; 315.917 331.695 … 466.85 466.405], "none", nothing, "red, very thick", "Intruder 1", nothing, nothing), PGFPlots.Plots.Linear(Real[1.0 2.0 … 65.0 66.0; 490.232 510.42 … 2643.84 2736.84], "none", nothing, "magenta, very thick", "Intruder 2", nothing, nothing), PGFPlots.Plots.Linear(Real[1.0 2.0 … 65.0 66.0; 1188.82 1172.37 … 3536.66 3628.68], "none", nothing, "pink, very thick", "Intruder 3", nothing, nothing), PGFPlots.Plots.Linear(Real[1.0 2.0 … 65.0 66.0; 150.0 150.0 … 150.0 150.0], "none", nothing, "black, very thick", "NMAC", nothing, nothing)], "Minimum Distance = 185.74448818684655 m", "Time Step (s)", nothing, "Distance (m)", nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, "5in", "2in", nothing, nothing, "{at={(0.05,0.95)}, anchor=north west}", nothing, nothing, nothing, nothing, nothing, "axis")], (1, 2), nothing, "vertical sep = 2cm" ...

# %%
trajViz(x0=0.0,
        y0=0.0,
        x_dest=2500.0,
        y_dest=-400.0, 
        CASType=:VICASClosest,
        policyFile="LOWFI_mid3_maxdist_2km_nmac_150m_Discount_0.95_ActWeight_0.5_IfSample_false_PenAction_3.0_PenConflict_50.0_PenCloseness_500.0_PenNmac_7000.0_Sigma_v_5.0_alert_5.0_theta_3.0_phi_7.0_coc_3.0_2018-11-13T18\:55\:43.491",
        intTrajFile="intTraj.csv",
        figName="")
# Out:
# PGFPlots.GroupPlot(PGFPlots.Axis[PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Linear(Real[0.0 50.0 … 2115.1 2136.5; 300.0 300.0 … -1899.3 -1944.5], "none", nothing, "forget plot, red, very thick", nothing, nothing, nothing), PGFPlots.Plots.Linear(Real[0.0 35.355 … 1934.8 1947.4; -500.0 -535.36 … 364.26 412.64], "none", nothing, "forget plot, magenta, very thick", nothing, nothing, nothing), PGFPlots.Plots.Linear(Real[0.0 50.0 … 1803.7 1820.6; -1200.0 -1200.0 … 1258.5 1305.5], "none", nothing, "forget plot, pink, very thick", nothing, nothing, nothing), PGFPlots.Plots.Linear(Real[48.4957 95.7459 … 2414.31 2460.57; -12.1725 -28.5254 … -364.866 -383.834], "none", nothing, "forget plot, black, very thick", nothing, nothing, nothing), PGFPlots.Plots.Scatter(Any[48.4957 95.7459 … 2414.31 2460.57; -12.1725 -28.5254 … -364.866 -383.834; -5.0 -5.0 … 0.0 0.0], "*", 1.2, nothing, "Ownship Actions", true, nothing), PGFPlots.Plots.Scatter(Any[0; 0], nothing, 3, "white, mark options={fill=black},mark=square*", "Start", true, nothing), PGFPlots.Plots.Scatter(Any[2500.0; -400.0], nothing, 3, "white, mark options={fill=green},mark=square*", "Destination", true, nothing), PGFPlots.Plots.Scatter(Any[0.0; 300.0], nothing, 3, "forget plot,white, mark options={fill=black},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[2136.5; -1944.5], nothing, 3, "forget plot,white, mark options={fill=green},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[0.0; -500.0], nothing, 3, "forget plot,white, mark options={fill=black},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[1947.4; 412.64], nothing, 3, "forget plot,white, mark options={fill=green},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[0.0; -1200.0], nothing, 3, "forget plot,white, mark options={fill=black},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[1820.6; 1305.5], nothing, 3, "forget plot,white, mark options={fill=green},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[438.46 860.23 … 1508.5 1770.3; 214.56 -50.389 … -807.58 -1233.4], nothing, 3, "very thick,solid,red,mark=diamond", "Intruder 1", true, nothing), PGFPlots.Plots.Scatter(Any[315.93 701.9 … 1506.5 1713.0; -820.44 -1136.3 … -806.67 -351.87], nothing, 3, "very thick,solid,magenta,mark=diamond", "Intruder 2", true, nothing), PGFPlots.Plots.Scatter(Any[425.64 793.99 … 1321.3 1529.9; -1076.2 -741.09 … 106.02 560.32], nothing, 3, "very thick,solid,pink,mark=diamond", "Intruder 3", true, nothing), PGFPlots.Plots.Scatter(Any[457.221 882.678 … 1720.37 2182.99; -194.921 -437.297 … -80.3518 -270.028], nothing, 3, "very thick,solid,black,mark=diamond", "Ownship Trajectory", true, nothing)], "VICASClosest", "x (m)", nothing, "y (m)", nothing, nothing, nothing, nothing, nothing, nothing, nothing, true, nothing, nothing, nothing, nothing, "5in", "5in", nothing, nothing, "{at={(0.02,0.02)}, anchor=south west}", nothing, nothing, true, nothing, nothing, "axis"), PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Linear(Real[1.0 2.0 … 55.0 56.0; 315.917 331.695 … 1207.07 1239.75], "none", nothing, "red, very thick", "Intruder 1", nothing, nothing), PGFPlots.Plots.Linear(Real[1.0 2.0 … 55.0 56.0; 490.232 510.42 … 667.433 722.75], "none", nothing, "magenta, very thick", "Intruder 2", nothing, nothing), PGFPlots.Plots.Linear(Real[1.0 2.0 … 55.0 56.0; 1188.82 1172.37 … 1399.53 1469.21], "none", nothing, "pink, very thick", "Intruder 3", nothing, nothing), PGFPlots.Plots.Linear(Real[1.0 2.0 … 55.0 56.0; 150.0 150.0 … 150.0 150.0], "none", nothing, "black, very thick", "NMAC", nothing, nothing)], "Minimum Distance = 67.51633124986468 m", "Time Step (s)", nothing, "Distance (m)", nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, "5in", "2in", nothing, nothing, "{at={(0.05,0.95)}, anchor=north west}", nothing, nothing, nothing, nothing, nothing, "axis")], (1, 2), nothing, "vertical sep = 2cm" ...

# %%
trajViz(x0=0.0,
        y0=0.0,
        x_dest=2500.0,
        y_dest=-400.0, 
        CASType=:NOCAS,
        policyFile="LOWFI_mid3_maxdist_2km_nmac_150m_Discount_0.95_ActWeight_0.5_IfSample_false_PenAction_3.0_PenConflict_50.0_PenCloseness_500.0_PenNmac_7000.0_Sigma_v_5.0_alert_5.0_theta_3.0_phi_7.0_coc_3.0_2018-11-13T18\:55\:43.491",
        intTrajFile="intTraj.csv",
        figName="")
# Out:
# PGFPlots.GroupPlot(PGFPlots.Axis[PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Linear(Real[0.0 50.0 … 2115.1 2136.5; 300.0 300.0 … -1899.3 -1944.5], "none", nothing, "forget plot, red, very thick", nothing, nothing, nothing), PGFPlots.Plots.Linear(Real[0.0 35.355 … 1934.8 1947.4; -500.0 -535.36 … 364.26 412.64], "none", nothing, "forget plot, magenta, very thick", nothing, nothing, nothing), PGFPlots.Plots.Linear(Real[0.0 50.0 … 1803.7 1820.6; -1200.0 -1200.0 … 1258.5 1305.5], "none", nothing, "forget plot, pink, very thick", nothing, nothing, nothing), PGFPlots.Plots.Linear(Real[49.372 98.7441 … 2419.23 2468.6; -7.89953 -15.7991 … -387.077 -394.976], "none", nothing, "forget plot, black, very thick", nothing, nothing, nothing), PGFPlots.Plots.Scatter(Any[49.372 98.7441 … 2419.23 2468.6; -7.89953 -15.7991 … -387.077 -394.976; 0.0 0.0 … 0.0 0.0], "*", 1.2, nothing, "Ownship Action = COC", true, nothing), PGFPlots.Plots.Scatter(Any[0; 0], nothing, 3, "white, mark options={fill=black},mark=square*", "Start", true, nothing), PGFPlots.Plots.Scatter(Any[2500.0; -400.0], nothing, 3, "white, mark options={fill=green},mark=square*", "Destination", true, nothing), PGFPlots.Plots.Scatter(Any[0.0; 300.0], nothing, 3, "forget plot,white, mark options={fill=black},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[2136.5; -1944.5], nothing, 3, "forget plot,white, mark options={fill=green},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[0.0; -500.0], nothing, 3, "forget plot,white, mark options={fill=black},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[1947.4; 412.64], nothing, 3, "forget plot,white, mark options={fill=green},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[0.0; -1200.0], nothing, 3, "forget plot,white, mark options={fill=black},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[1820.6; 1305.5], nothing, 3, "forget plot,white, mark options={fill=green},mark=square*", nothing, true, nothing), PGFPlots.Plots.Scatter(Any[438.46 860.23 … 1508.5 1770.3; 214.56 -50.389 … -807.58 -1233.4], nothing, 3, "very thick,solid,red,mark=diamond", "Intruder 1", true, nothing), PGFPlots.Plots.Scatter(Any[315.93 701.9 … 1506.5 1713.0; -820.44 -1136.3 … -806.67 -351.87], nothing, 3, "very thick,solid,magenta,mark=diamond", "Intruder 2", true, nothing), PGFPlots.Plots.Scatter(Any[425.64 793.99 … 1321.3 1529.9; -1076.2 -741.09 … 106.02 560.32], nothing, 3, "very thick,solid,pink,mark=diamond", "Intruder 3", true, nothing), PGFPlots.Plots.Scatter(Any[493.72 987.441 … 1974.88 2468.6; -78.9953 -157.991 … -315.981 -394.976], nothing, 3, "very thick,solid,black,mark=diamond", "Ownship Trajectory", true, nothing)], "NOCAS", "x (m)", nothing, "y (m)", nothing, nothing, nothing, nothing, nothing, nothing, nothing, true, nothing, nothing, nothing, nothing, "5in", "5in", nothing, nothing, "{at={(0.02,0.02)}, anchor=south west}", nothing, nothing, false, nothing, nothing, "axis"), PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Linear(Real[1.0 2.0 … 49.0 50.0; 311.833 319.539 … 1048.14 1091.14], "none", nothing, "red, very thick", "Intruder 1", nothing, nothing), PGFPlots.Plots.Linear(Real[1.0 2.0 … 49.0 50.0; 494.571 523.414 … 724.122 756.83], "none", nothing, "magenta, very thick", "Intruder 2", nothing, nothing), PGFPlots.Plots.Linear(Real[1.0 2.0 … 49.0 50.0; 1193.12 1185.2 … 1280.23 1339.31], "none", nothing, "pink, very thick", "Intruder 3", nothing, nothing), PGFPlots.Plots.Linear(Real[1.0 2.0 … 49.0 50.0; 150.0 150.0 … 150.0 150.0], "none", nothing, "black, very thick", "NMAC", nothing, nothing)], "Minimum Distance = 161.39873585051578 m", "Time Step (s)", nothing, "Distance (m)", nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, "5in", "2in", nothing, nothing, "{at={(0.05,0.95)}, anchor=north west}", nothing, nothing, nothing, nothing, nothing, "axis")], (1, 2), nothing, "vertical sep = 2cm")
